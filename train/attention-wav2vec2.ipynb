# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# !pip install datasets --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.4/491.4 kB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 18.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 15.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.

# %%
import os

FILE_NAME = "LibriSeVoc-500"
ZIP_PATH = f"/content/drive/MyDrive/Datasets/{FILE_NAME}"

if not os.path.exists(f'/content/${FILE_NAME}'):
  # !unzip {ZIP_PATH} -d /content/
else:
  print("Dataset already extracted.")
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/LibriSeVoc-500/wavernn/8312_279791_000038_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8312_279791_000038_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7178_34644_000018_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7178_34644_000018_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5678_43301_000006_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5678_43301_000006_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/3440_171009_000032_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._3440_171009_000032_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7402_59171_000005_000008_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7402_59171_000005_000008_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7178_34644_000096_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7178_34644_000096_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5163_39921_000037_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5163_39921_000037_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8088_284756_000058_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8088_284756_000058_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2196_170379_000013_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2196_170379_000013_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/3526_176653_000080_000007_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._3526_176653_000080_000007_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/201_122255_000016_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._201_122255_000016_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8797_294123_000004_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8797_294123_000004_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1116_137572_000021_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1116_137572_000021_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/3699_175950_000011_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._3699_175950_000011_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6454_93938_000015_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6454_93938_000015_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1553_140048_000006_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1553_140048_000006_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/250_140277_000004_000009_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._250_140277_000004_000009_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6019_3185_000031_000009_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6019_3185_000031_000009_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/87_121553_000162_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._87_121553_000162_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6064_56165_000051_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6064_56165_000051_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6147_34607_000013_000028_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6147_34607_000013_000028_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6147_34606_000013_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6147_34606_000013_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/887_123291_000015_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._887_123291_000015_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/887_123289_000008_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._887_123289_000008_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6078_54007_000051_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6078_54007_000051_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1069_133699_000066_000011_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1069_133699_000066_000011_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7517_100442_000007_000006_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7517_100442_000007_000006_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/4680_16042_000019_000006_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._4680_16042_000019_000006_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1355_39947_000002_000008_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1355_39947_000002_000008_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/40_121026_000225_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._40_121026_000225_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/481_123720_000044_000007_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._481_123720_000044_000007_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1502_122615_000033_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1502_122615_000033_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6367_65536_000003_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6367_65536_000003_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2836_5354_000022_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2836_5354_000022_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5322_7679_000033_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5322_7679_000033_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6818_76332_000034_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6818_76332_000034_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/118_47824_000088_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._118_47824_000088_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/4297_13006_000065_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._4297_13006_000065_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/4680_16042_000016_000006_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._4680_16042_000016_000006_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7190_90543_000006_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7190_90543_000006_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8108_280359_000006_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8108_280359_000006_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8123_275216_000058_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8123_275216_000058_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2910_131096_000039_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2910_131096_000039_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/403_126855_000013_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._403_126855_000013_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/4397_15678_000004_000008_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._4397_15678_000004_000008_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/3214_167602_000056_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._3214_167602_000056_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/3857_182317_000026_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._3857_182317_000026_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5750_100289_000037_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5750_100289_000037_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/40_121026_000100_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._40_121026_000100_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7402_59171_000015_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7402_59171_000015_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8088_284756_000134_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8088_284756_000134_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7367_86737_000132_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7367_86737_000132_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2002_139469_000007_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2002_139469_000007_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2196_170379_000011_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2196_170379_000011_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7447_91187_000006_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7447_91187_000006_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/200_126784_000040_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._200_126784_000040_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5163_39921_000024_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5163_39921_000024_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1355_39947_000022_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1355_39947_000022_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2436_2476_000004_000006_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2436_2476_000004_000006_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8123_275209_000007_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8123_275209_000007_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1624_142933_000009_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1624_142933_000009_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5561_41615_000023_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5561_41615_000023_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8123_275216_000028_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8123_275216_000028_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7447_91186_000026_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7447_91186_000026_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5393_19219_000052_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5393_19219_000052_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/3879_174923_000006_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._3879_174923_000006_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8123_275193_000008_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8123_275193_000008_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7178_34645_000026_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7178_34645_000026_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5339_14133_000018_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5339_14133_000018_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1263_138246_000003_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1263_138246_000003_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/118_47824_000083_000008_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._118_47824_000083_000008_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7178_34645_000035_000009_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7178_34645_000035_000009_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2196_170379_000008_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2196_170379_000008_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6272_70168_000027_000014_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6272_70168_000027_000014_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/887_123290_000012_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._887_123290_000012_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1594_135914_000037_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1594_135914_000037_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2911_15045_000002_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2911_15045_000002_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8580_287364_000052_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8580_287364_000052_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/87_121553_000100_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._87_121553_000100_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2843_152918_000001_000014_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2843_152918_000001_000014_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/3699_19402_000015_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._3699_19402_000015_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5750_100289_000007_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5750_100289_000007_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/4267_287369_000019_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._4267_287369_000019_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8797_294123_000016_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8797_294123_000016_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7511_102420_000019_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7511_102420_000019_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/4137_11702_000032_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._4137_11702_000032_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1553_140048_000004_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1553_140048_000004_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/60_121082_000005_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._60_121082_000005_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/3526_176651_000012_000016_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._3526_176651_000012_000016_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/125_121124_000028_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._125_121124_000028_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/3240_131232_000081_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._3240_131232_000081_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8123_275216_000059_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8123_275216_000059_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8108_274318_000005_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8108_274318_000005_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/3440_171009_000137_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._3440_171009_000137_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/4813_248641_000011_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._4813_248641_000011_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2911_15045_000013_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2911_15045_000013_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/200_126784_000049_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._200_126784_000049_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5339_14133_000018_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5339_14133_000018_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1263_141777_000019_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1263_141777_000019_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5867_48852_000005_000007_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5867_48852_000005_000007_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5322_7680_000062_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5322_7680_000062_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/201_122255_000015_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._201_122255_000015_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/4051_11217_000013_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._4051_11217_000013_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/298_126791_000077_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._298_126791_000077_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6209_34599_000017_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6209_34599_000017_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5789_57158_000068_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5789_57158_000068_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8063_274117_000027_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8063_274117_000027_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6078_54007_000045_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6078_54007_000045_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2518_154825_000021_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2518_154825_000021_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5867_48852_000072_000006_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5867_48852_000072_000006_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/4406_16883_000001_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._4406_16883_000001_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/3879_174923_000020_000006_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._3879_174923_000020_000006_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/4297_13006_000013_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._4297_13006_000013_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2910_131096_000022_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2910_131096_000022_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7059_77900_000028_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7059_77900_000028_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/3664_178355_000010_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._3664_178355_000010_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1116_137572_000004_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1116_137572_000004_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6272_70171_000035_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6272_70171_000035_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5322_7678_000006_000013_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5322_7678_000006_000013_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7178_34645_000028_000010_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7178_34645_000028_000010_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/250_142276_000015_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._250_142276_000015_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/446_123501_000019_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._446_123501_000019_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/831_130739_000032_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._831_130739_000032_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1743_142914_000025_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1743_142914_000025_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5778_54535_000017_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5778_54535_000017_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1553_140048_000057_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1553_140048_000057_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7078_271888_000006_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7078_271888_000006_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8838_298546_000054_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8838_298546_000054_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/3240_131231_000036_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._3240_131231_000036_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6818_76332_000046_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6818_76332_000046_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/250_140277_000003_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._250_140277_000003_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2910_131096_000026_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2910_131096_000026_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7635_105661_000011_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7635_105661_000011_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8312_279791_000048_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8312_279791_000048_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6415_111615_000019_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6415_111615_000019_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8838_298546_000021_000008_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8838_298546_000021_000008_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/405_130895_000061_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._405_130895_000061_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8088_284756_000022_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8088_284756_000022_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7059_77897_000033_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7059_77897_000033_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/4406_16883_000016_000012_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._4406_16883_000016_000012_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/40_222_000006_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._40_222_000006_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7302_86814_000002_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7302_86814_000002_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7402_90848_000041_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7402_90848_000041_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2911_15084_000007_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2911_15084_000007_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/32_4137_000006_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._32_4137_000006_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7067_76048_000064_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7067_76048_000064_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/201_122255_000010_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._201_122255_000010_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1502_122619_000003_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1502_122619_000003_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8098_278278_000017_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8098_278278_000017_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/3526_176653_000050_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._3526_176653_000050_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5322_7679_000021_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5322_7679_000021_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/587_54108_000014_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._587_54108_000014_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5463_39173_000062_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5463_39173_000062_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8468_294887_000012_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8468_294887_000012_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5678_43302_000027_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5678_43302_000027_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2092_145706_000052_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2092_145706_000052_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/200_126784_000027_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._200_126784_000027_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8098_278278_000004_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8098_278278_000004_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5322_7680_000019_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5322_7680_000019_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/250_142276_000003_000009_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._250_142276_000003_000009_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/3242_67153_000004_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._3242_67153_000004_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7402_90848_000043_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7402_90848_000043_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1246_124548_000008_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1246_124548_000008_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6078_54007_000028_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6078_54007_000028_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2691_156755_000009_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2691_156755_000009_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/4195_186237_000007_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._4195_186237_000007_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8098_278278_000010_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8098_278278_000010_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8797_294123_000020_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8797_294123_000020_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/26_496_000030_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._26_496_000030_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/426_122821_000030_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._426_122821_000030_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1116_137572_000015_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1116_137572_000015_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8238_274553_000027_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8238_274553_000027_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7505_83618_000015_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7505_83618_000015_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/696_93314_000023_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._696_93314_000023_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2514_149482_000011_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2514_149482_000011_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5778_54535_000012_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5778_54535_000012_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/32_4137_000005_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._32_4137_000005_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6367_74004_000018_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6367_74004_000018_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1355_39947_000013_000009_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1355_39947_000013_000009_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8629_261139_000033_000006_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8629_261139_000033_000006_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5652_19215_000030_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5652_19215_000030_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/4195_17507_000068_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._4195_17507_000068_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6019_3185_000022_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6019_3185_000022_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/3240_131231_000027_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._3240_131231_000027_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5393_19219_000043_000009_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5393_19219_000043_000009_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2092_145706_000029_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2092_145706_000029_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1263_138246_000004_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1263_138246_000004_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8630_305212_000010_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8630_305212_000010_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7447_91186_000029_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7447_91186_000029_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7059_77897_000028_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7059_77897_000028_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2289_152254_000020_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2289_152254_000020_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/374_180298_000009_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._374_180298_000009_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5514_19193_000008_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5514_19193_000008_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/87_121553_000240_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._87_121553_000240_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/4137_11701_000080_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._4137_11701_000080_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7505_258958_000017_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7505_258958_000017_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8108_280354_000007_000007_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8108_280354_000007_000007_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6437_66172_000013_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6437_66172_000013_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6476_57446_000042_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6476_57446_000042_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/200_124140_000026_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._200_124140_000026_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1246_124550_000028_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1246_124550_000028_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1116_137572_000015_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1116_137572_000015_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2514_149482_000008_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2514_149482_000008_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/200_126784_000026_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._200_126784_000026_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/4267_78186_000004_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._4267_78186_000004_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/696_92939_000012_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._696_92939_000012_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/730_359_000017_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._730_359_000017_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1355_39947_000005_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1355_39947_000005_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8770_295463_000037_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8770_295463_000037_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1263_139804_000005_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1263_139804_000005_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5393_19219_000043_000010_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5393_19219_000043_000010_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8629_261139_000014_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8629_261139_000014_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6081_42010_000004_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6081_42010_000004_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6848_76049_000005_000010_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6848_76049_000005_000010_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7447_91187_000016_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7447_91187_000016_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/200_124140_000020_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._200_124140_000020_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6209_34600_000007_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6209_34600_000007_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7517_100437_000007_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7517_100437_000007_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6385_220959_000014_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6385_220959_000014_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2910_131096_000019_000006_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2910_131096_000019_000006_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6437_66173_000030_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6437_66173_000030_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/412_126975_000051_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._412_126975_000051_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/412_126975_000009_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._412_126975_000009_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1867_154075_000073_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1867_154075_000073_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/4267_72637_000015_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._4267_72637_000015_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6081_42010_000005_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6081_42010_000005_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6019_3185_000031_000012_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6019_3185_000031_000012_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1116_137572_000002_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1116_137572_000002_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/4397_15666_000010_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._4397_15666_000010_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/460_172359_000006_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._460_172359_000006_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7113_86041_000016_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7113_86041_000016_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/446_123501_000002_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._446_123501_000002_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5322_7679_000018_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5322_7679_000018_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5322_7678_000007_000008_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5322_7678_000007_000008_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6848_252323_000055_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6848_252323_000055_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7078_271888_000060_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7078_271888_000060_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/4267_78186_000006_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._4267_78186_000006_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/2691_156755_000017_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._2691_156755_000017_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8630_305212_000006_000007_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8630_305212_000006_000007_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7447_91186_000023_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7447_91186_000023_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8088_284756_000105_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8088_284756_000105_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5561_41616_000034_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5561_41616_000034_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5750_100289_000036_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5750_100289_000036_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1246_124548_000007_000006_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1246_124548_000007_000006_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1502_122615_000049_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1502_122615_000049_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/60_121082_000009_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._60_121082_000009_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/412_126975_000087_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._412_126975_000087_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/254_145458_000012_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._254_145458_000012_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1594_135914_000036_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1594_135914_000036_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1246_124548_000027_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1246_124548_000027_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6437_66172_000005_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6437_66172_000005_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1898_145724_000017_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1898_145724_000017_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/446_123502_000009_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._446_123502_000009_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5867_48852_000071_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5867_48852_000071_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5867_48852_000082_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5867_48852_000082_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6147_34605_000033_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6147_34605_000033_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1737_142397_000032_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1737_142397_000032_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6272_70168_000046_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6272_70168_000046_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8098_275181_000004_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8098_275181_000004_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5703_47198_000017_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5703_47198_000017_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/4481_17498_000051_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._4481_17498_000051_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8770_295462_000041_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8770_295462_000041_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6454_93938_000032_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6454_93938_000032_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/201_122255_000031_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._201_122255_000031_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7367_86737_000122_000010_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7367_86737_000122_000010_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/302_123516_000027_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._302_123516_000027_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1502_122619_000032_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._1502_122619_000032_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7780_274562_000008_000018_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7780_274562_000008_000018_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5390_24512_000046_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5390_24512_000046_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8747_293952_000111_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8747_293952_000111_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6019_3185_000029_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6019_3185_000029_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/5322_7679_000003_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._5322_7679_000003_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/6454_93938_000031_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._6454_93938_000031_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/27_123349_000001_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._27_123349_000001_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/3830_12530_000021_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._3830_12530_000021_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7113_86041_000024_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7113_86041_000024_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/7505_258964_000018_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._7505_258964_000018_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/4362_15663_000036_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._4362_15663_000036_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/8468_286673_000009_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/wavernn/._8468_286673_000009_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/wavernn/1040_133433_000076_000000_gen.wav
# ...
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._27_124992_000026_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/200_124140_000031_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._200_124140_000031_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/374_180298_000016_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._374_180298_000016_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/412_126975_000051_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._412_126975_000051_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/78_369_000057_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._78_369_000057_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/4051_11218_000013_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._4051_11218_000013_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/200_126784_000074_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._200_126784_000074_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/4051_11218_000000_000008_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._4051_11218_000000_000008_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/6437_66172_000011_000010_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._6437_66172_000011_000010_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/6272_70168_000027_000011_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._6272_70168_000027_000011_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/5393_19218_000033_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._5393_19218_000033_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/8108_274318_000001_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._8108_274318_000001_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/6476_96661_000007_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._6476_96661_000007_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/5456_62043_000025_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._5456_62043_000025_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/8051_295385_000006_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._8051_295385_000006_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/196_122150_000007_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._196_122150_000007_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/4406_16882_000027_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._4406_16882_000027_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/32_21631_000007_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._32_21631_000007_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/6081_41998_000031_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._6081_41998_000031_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/3235_28452_000015_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._3235_28452_000015_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/3879_173592_000031_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._3879_173592_000031_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/2836_5355_000035_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._2836_5355_000035_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/1040_133433_000071_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._1040_133433_000071_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/8747_293952_000098_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._8747_293952_000098_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/730_358_000001_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._730_358_000001_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/7800_283492_000036_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._7800_283492_000036_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/7859_102519_000004_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._7859_102519_000004_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/6367_65536_000038_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._6367_65536_000038_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/1183_128659_000003_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._1183_128659_000003_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/8238_283452_000024_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._8238_283452_000024_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/7178_34645_000006_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._7178_34645_000006_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/6209_34599_000017_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._6209_34599_000017_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/7505_258964_000023_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._7505_258964_000023_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/196_122150_000006_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._196_122150_000006_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/6019_3185_000014_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._6019_3185_000014_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/3436_172171_000016_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._3436_172171_000016_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/8226_274369_000032_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._8226_274369_000032_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/3374_298026_000002_000005_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._3374_298026_000002_000005_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/1455_134435_000015_000011_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._1455_134435_000015_000011_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/6147_34607_000011_000010_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._6147_34607_000011_000010_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/3436_172171_000010_000009_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._3436_172171_000010_000009_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/1363_139304_000017_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._1363_139304_000017_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/3235_28433_000019_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._3235_28433_000019_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/8630_305212_000015_000008_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._8630_305212_000015_000008_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/3526_176653_000071_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._3526_176653_000071_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/7059_77897_000016_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._7059_77897_000016_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/5390_30096_000028_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._5390_30096_000028_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/8468_286673_000013_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._8468_286673_000013_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/4137_11702_000007_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._4137_11702_000007_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/7447_91186_000007_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._7447_91186_000007_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/1116_132847_000023_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._1116_132847_000023_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/26_495_000046_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._26_495_000046_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/458_126290_000004_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._458_126290_000004_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/4680_16042_000020_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._4680_16042_000020_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/7067_76048_000044_000008_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._7067_76048_000044_000008_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/1447_17506_000022_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._1447_17506_000022_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/2893_139322_000006_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._2893_139322_000006_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/7505_258964_000028_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._7505_258964_000028_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/5652_19215_000008_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._5652_19215_000008_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/5339_14134_000083_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._5339_14134_000083_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/7780_274562_000005_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._7780_274562_000005_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/8975_270782_000014_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._8975_270782_000014_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/200_124139_000027_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._200_124139_000027_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/2843_152918_000000_000008_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._2843_152918_000000_000008_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/1116_132851_000039_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._1116_132851_000039_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/8051_118101_000010_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._8051_118101_000010_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/1355_39947_000009_000007_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._1355_39947_000009_000007_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/6454_120342_000008_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._6454_120342_000008_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/8312_279791_000030_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._8312_279791_000030_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/4018_107338_000033_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._4018_107338_000033_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/8797_294123_000015_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._8797_294123_000015_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/32_4137_000024_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._32_4137_000024_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/2910_131096_000013_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._2910_131096_000013_000003_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/78_369_000043_000009_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._78_369_000043_000009_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/3830_12535_000011_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._3830_12535_000011_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/7511_102420_000007_000006_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._7511_102420_000007_000006_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/89_218_000014_000007_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._89_218_000014_000007_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/5463_39174_000007_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._5463_39174_000007_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/1098_133695_000014_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._1098_133695_000014_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/8580_287364_000014_000002_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._8580_287364_000014_000002_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/6529_62556_000097_000004_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._6529_62556_000097_000004_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/6529_62554_000047_000001_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._6529_62554_000047_000001_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/4051_10927_000023_000000_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._4051_10927_000023_000000_gen.wav
#   inflating: /content/LibriSeVoc-500/parallel_wave_gan/2817_142371_000032_000003_gen.wav
#   inflating: /content/__MACOSX/LibriSeVoc-500/parallel_wave_gan/._2817_142371_000032_000003_gen.wav

# %%
# prompt: move /content/LibriSeVoc-500/__MACOSX and /content/LibriSeVoc-500/LibriSeVoc-500 outside

import shutil

# Move __MACOSX
source_path_macosx = "/content/LibriSeVoc-500/__MACOSX"
destination_path_macosx = "/content/__MACOSX"
if os.path.exists(source_path_macosx):
  shutil.move(source_path_macosx, destination_path_macosx)

# Move LibriSeVoc-500
source_path_libri = "/content/LibriSeVoc-500/LibriSeVoc-500"
destination_path_libri = "/content/LibriSeVoc-500_moved"
if os.path.exists(source_path_libri):
  shutil.move(source_path_libri, destination_path_libri)

# %%
# Step 3: Data Preparation and Loading (Adapted for Kaggle Structure)

import os
import pandas as pd
from sklearn.model_selection import train_test_split
from datasets import Dataset, DatasetDict, Audio, ClassLabel # Import ClassLabel
from pathlib import Path
import tensorflow as tf # Import tensorflow for dataset check later

# --- 1. Define Paths and Labels ---
# Adjust this path based on where Kaggle mounts the dataset
data_dir = Path(f'/content/{FILE_NAME}')

# Get class names from subdirectory names
class_names = sorted([d.name for d in data_dir.iterdir() if d.is_dir()])
num_labels = len(class_names)
label2id = {name: i for i, name in enumerate(class_names)}
id2label = {i: name for name, i in label2id.items()}

print(f"Found {num_labels} classes: {class_names}")
print(f"Label mapping: {label2id}")

# --- 2. Scan for Audio Files and Assign Labels ---
all_files = []
print("Scanning for audio files...")
for class_name in class_names:
    class_dir = data_dir / class_name
    # Using rglob to find files recursively, just in case
    for file_path in class_dir.rglob('*.wav'):
        # Extract a base identifier for splitting (important!)
        # Assuming filename format like 'speaker_chapter_segment_instance.wav'
        # We want to group by 'speaker_chapter_segment' to keep variations together
        base_filename = '_'.join(file_path.stem.split('_')[:3]) # Adjust if format differs

        all_files.append({
            'file_path': str(file_path),
            'label_id': label2id[class_name],
            'class_name': class_name,
            'base_filename': base_filename
        })
print(f"Found {len(all_files)} audio files.")

if not all_files:
    raise ValueError(f"No .wav files found in {data_dir}. Please check the path and dataset structure.")

all_files_df = pd.DataFrame(all_files)

# --- 3. Split Data (Stratified by Base Filename) ---
# This strategy ensures different versions (real/fake) of the same utterance
# stay within the same split (train, val, or test).
unique_base_filenames = all_files_df['base_filename'].unique()

# Split the unique base filenames first (e.g., 70% train, 15% val, 15% test)
train_base, test_val_base = train_test_split(unique_base_filenames, test_size=0.3, random_state=42)
val_base, test_base = train_test_split(test_val_base, test_size=0.5, random_state=42) # Split remaining 30% into 15%/15%

# Create the final data splits based on these base filenames
train_df = all_files_df[all_files_df['base_filename'].isin(train_base)].copy()
val_df = all_files_df[all_files_df['base_filename'].isin(val_base)].copy()
test_df = all_files_df[all_files_df['base_filename'].isin(test_base)].copy()

print(f"Train samples: {len(train_df)}, Validation samples: {len(val_df)}, Test samples: {len(test_df)}")
print(f"Example Train DF entry:\n{train_df.head()}")

# --- 4. Create Hugging Face DatasetDict ---
train_dataset = Dataset.from_pandas(train_df, preserve_index=False)
val_dataset = Dataset.from_pandas(val_df, preserve_index=False)
test_dataset = Dataset.from_pandas(test_df, preserve_index=False)

# --- 5. Cast Audio Column and Set Class Labels ---
sampling_rate = 16000 # wav2vec 2.0 expects 16kHz
print(f"Casting audio column to {sampling_rate} Hz...")

# Define the ClassLabel feature using the discovered class names
class_label_feature = ClassLabel(names=class_names)

def cast_and_set_features(dataset):
    dataset = dataset.cast_column("file_path", Audio(sampling_rate=sampling_rate))
    # Important: Cast the label_id column to ClassLabel AFTER loading audio
    # This helps Hugging Face understand the label mapping
    features = dataset.features.copy()
    features['label_id'] = class_label_feature
    dataset = dataset.cast(features)
    # Rename columns for consistency
    dataset = dataset.rename_column("file_path", "audio")
    return dataset

train_dataset = cast_and_set_features(train_dataset)
val_dataset = cast_and_set_features(val_dataset)
test_dataset = cast_and_set_features(test_dataset)

librisevoc_dataset_dict = DatasetDict({
    "train": train_dataset,
    "validation": val_dataset,
    "test": test_dataset
})

print("DatasetDict created successfully:")
print(librisevoc_dataset_dict)
print("\nExample Train entry features:")
print(librisevoc_dataset_dict['train'][0])
# Out:
# Found 7 classes: ['diffwave', 'gt', 'melgan', 'parallel_wave_gan', 'wavegrad', 'wavenet', 'wavernn']
# Label mapping: {'diffwave': 0, 'gt': 1, 'melgan': 2, 'parallel_wave_gan': 3, 'wavegrad': 4, 'wavenet': 5, 'wavernn': 6}
# Scanning for audio files...
# Found 3500 audio files.
# Train samples: 2458, Validation samples: 517, Test samples: 525
# Example Train DF entry:
#                                            file_path  label_id class_name  \
# 0  /content/LibriSeVoc-500/diffwave/460_172359_00...         0   diffwave
# 1  /content/LibriSeVoc-500/diffwave/254_27760_000...         0   diffwave
# 2  /content/LibriSeVoc-500/diffwave/5393_19219_00...         0   diffwave
# 3  /content/LibriSeVoc-500/diffwave/7190_90543_00...         0   diffwave
# 4  /content/LibriSeVoc-500/diffwave/5322_7678_000...         0   diffwave
#
#        base_filename
# 0  460_172359_000020
# 1   254_27760_000016
# 2  5393_19219_000047
# 3  7190_90543_000040
# 4   5322_7678_000007
# Casting audio column to 16000 Hz...
# Casting the dataset:   0%|          | 0/2458 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/517 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/525 [00:00<?, ? examples/s]
# DatasetDict created successfully:
# DatasetDict({
#     train: Dataset({
#         features: ['audio', 'label_id', 'class_name', 'base_filename'],
#         num_rows: 2458
#     })
#     validation: Dataset({
#         features: ['audio', 'label_id', 'class_name', 'base_filename'],
#         num_rows: 517
#     })
#     test: Dataset({
#         features: ['audio', 'label_id', 'class_name', 'base_filename'],
#         num_rows: 525
#     })
# })
#
# Example Train entry features:
# {'audio': {'path': '/content/LibriSeVoc-500/diffwave/460_172359_000020_000000_gen.wav', 'array': array([ 0.00623519,  0.00286017,  0.00108559, ..., -0.00044471,
#         0.00170136,  0.        ]), 'sampling_rate': 16000}, 'label_id': 0, 'class_name': 'diffwave', 'base_filename': '460_172359_000020'}

# %%
from transformers import AutoFeatureExtractor, TFAutoModelForAudioClassification
import tensorflow as tf

# Example: 7 classes (1 real + 6 vocoders)
num_labels = 7
model_checkpoint = "facebook/wav2vec2-base" # Or other variants like large

feature_extractor = AutoFeatureExtractor.from_pretrained(model_checkpoint)

# Load TF model. Use from_pt=True if HF only has PyTorch weights for this checkpoint
try:
    model = TFAutoModelForAudioClassification.from_pretrained(
        model_checkpoint,
        num_labels=num_labels
    )
except OSError: # Handle case where only PyTorch weights are available
     print("No TF weights found, loading from PyTorch weights...")
     model = TFAutoModelForAudioClassification.from_pretrained(
        model_checkpoint,
        num_labels=num_labels,
        from_pt=True
    )

# Verify model summary (optional)
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/159 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/configuration_utils.py:311: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# No TF weights found, loading from PyTorch weights...
# pytorch_model.bin:   0%|          | 0.00/380M [00:00<?, ?B/s]
# TFWav2Vec2ForSequenceClassification has backpropagation operations that are NOT supported on CPU. If you wish to train/fine-tune this model, you need a GPU or a TPU
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFWav2Vec2ForSequenceClassification: ['project_q.weight', 'project_hid.weight', 'quantizer.weight_proj.weight', 'quantizer.weight_proj.bias', 'project_q.bias', 'project_hid.bias', 'quantizer.codevectors']
# - This IS expected if you are initializing TFWav2Vec2ForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFWav2Vec2ForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFWav2Vec2ForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['projector.weight', 'projector.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model: "tf_wav2_vec2_for_sequence_classification"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  wav2vec2 (TFWav2Vec2MainLa  multiple                  94371712
#  yer)
#
#  projector (Dense)           multiple                  196864
#
#  classifier (Dense)          multiple                  1799
#
# =================================================================
# Total params: 94570375 (360.76 MB)
# Trainable params: 94570375 (360.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
def preprocess_function(examples):
    audio_arrays = [x["array"] for x in examples["audio"]]
    inputs = feature_extractor(
        audio_arrays,
        sampling_rate=feature_extractor.sampling_rate,
        max_length=int(feature_extractor.sampling_rate * 4.0),
        truncation=True,
        padding='max_length',
        return_attention_mask=True  # Add this line to get attention mask
    )
    # **Make sure 'input_values' and 'attention_mask' are present in the output:**
    return {
        'input_values': inputs.input_values,
        'attention_mask': inputs.attention_mask
    }

# %%
encoded_dataset = librisevoc_dataset_dict.map(
    preprocess_function,
    remove_columns=["audio"], # Remove original audio column
    batched=True
)
# Ensure label column is named 'labels' if your model expects it, otherwise adjust
# If your label column is 'label_id', you might not need renaming
# encoded_dataset = encoded_dataset.rename_column("label_id", "labels")
# Out:
# Map:   0%|          | 0/2458 [00:00<?, ? examples/s]
# Map:   0%|          | 0/517 [00:00<?, ? examples/s]
# Map:   0%|          | 0/525 [00:00<?, ? examples/s]

# %%
from transformers import DefaultDataCollator

# Use TF tensors for the collator
data_collator = DefaultDataCollator(return_tensors="tf")
batch_size = 16 # Adjust based on GPU memory

# Identify columns for the model input (usually 'input_values', 'attention_mask')
model_input_columns = ['input_values', 'attention_mask'] # Verify based on feature_extractor output

tf_train_dataset = encoded_dataset["train"].to_tf_dataset(
    columns=model_input_columns,
    label_cols=["label_id"], # Specify your label column name
    shuffle=True,
    batch_size=batch_size,
    collate_fn=data_collator,
)

tf_eval_dataset = encoded_dataset["validation"].to_tf_dataset(
    columns=model_input_columns,
    label_cols=["label_id"],
    shuffle=False, # No shuffle for validation/test
    batch_size=batch_size,
    collate_fn=data_collator,
)

tf_test_dataset = encoded_dataset["test"].to_tf_dataset(
    columns=model_input_columns,
    label_cols=["label_id"],
    shuffle=False,
    batch_size=batch_size,
    collate_fn=data_collator,
)
# Out:
# /usr/local/lib/python3.11/dist-packages/datasets/arrow_dataset.py:400: FutureWarning: The output of `to_tf_dataset` will change when a passing single element list for `labels` or `columns` in the next datasets version. To return a tuple structure rather than dict, pass a single string.
# Old behaviour: columns=['a'], labels=['labels'] -> (tf.Tensor, tf.Tensor)
#              : columns='a', labels='labels' -> (tf.Tensor, tf.Tensor)
# New behaviour: columns=['a'],labels=['labels'] -> ({'a': tf.Tensor}, {'labels': tf.Tensor})
#              : columns='a', labels='labels' -> (tf.Tensor, tf.Tensor)
#   warnings.warn(

# %%
# Remove the previous AdamW imports

from transformers import create_optimizer # Import the HF utility
from tensorflow.keras.losses import SparseCategoricalCrossentropy
import tensorflow as tf # Make sure tensorflow is imported

# --- Configuration for the optimizer ---
num_epochs = 3
# Ensure this batch_size matches what you use when creating the tf.data.Dataset later
# It's needed here to calculate the total training steps.
batch_size = 16
learning_rate = 3e-5

# Calculate the total number of training steps - REQUIRED for create_optimizer
try:
    # Need the size of the original HF dataset before converting to tf.data.Dataset
    num_train_examples = len(encoded_dataset["train"])
    num_train_steps = (num_train_examples // batch_size) * num_epochs
    # Optional: Define warmup steps (e.g., 10% of training steps)
    num_warmup_steps = int(num_train_steps * 0.1)
    print(f"Calculated training steps: {num_train_steps}, Warmup steps: {num_warmup_steps}")
except NameError:
     raise NameError("Please ensure 'encoded_dataset' (the mapped Hugging Face dataset)"
                     " and 'batch_size' are defined before this cell.")
except KeyError:
     raise KeyError("Please ensure 'encoded_dataset' has a 'train' split.")


# Create the optimizer and learning rate schedule using the HF utility
optimizer, schedule = create_optimizer(
    init_lr=learning_rate,
    num_train_steps=num_train_steps,
    num_warmup_steps=num_warmup_steps
    # You can also specify weight_decay_rate here if needed, e.g., weight_decay_rate=0.01
)

# Compile the model using the optimizer created by the utility
print("Compiling model with optimizer from create_optimizer...")
model.compile(
    optimizer=optimizer,  # Use the optimizer instance from create_optimizer
    loss=SparseCategoricalCrossentropy(from_logits=True),
    metrics=["accuracy"]
)
print("Model compiled successfully.")

# --- Now proceed to model.fit() ---
# The learning rate schedule created by `create_optimizer` will be applied automatically during training.
# history = model.fit(tf_train_dataset, validation_data=tf_eval_dataset, epochs=num_epochs)
# Out:
# Calculated training steps: 459, Warmup steps: 45
# Compiling model with optimizer from create_optimizer...
# Model compiled successfully.

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from transformers.keras_callbacks import PushToHubCallback
num_epochs = 3
batch_size = 16 # Adjust based on GPU memory
learning_rate = 3e-5
# Define output directory for checkpoints
checkpoint_output_dir = "wav2vec2_librisevoc_checkpoints" # Base directory
keras_checkpoint_filepath = os.path.join(checkpoint_output_dir, "best_model_keras.keras")
hf_callback_checkpoint_dir = os.path.join(checkpoint_output_dir, "best_model_hf_callback")

print("\nAttempting fallback training using PushToHubCallback...")
# Define a placeholder Hub model ID (required by callback structure)
# CHANGE THIS to your actual HF username and desired model name if you plan to push
hub_model_id = "ronanhansel/deepfake-audio-detector" # CHANGE THIS

push_to_hub_callback = PushToHubCallback(
    output_dir=hf_callback_checkpoint_dir, # Save to a different dir
    tokenizer=feature_extractor,
    hub_model_id=hub_model_id,
    save_strategy="epoch", # Save checkpoints every epoch
)
print(f"PushToHubCallback configured to save best model locally in: {push_to_hub_callback.output_dir}")

# Re-create optimizer and re-compile (safer after failed fit attempt)
optimizer, schedule = create_optimizer(
      init_lr=learning_rate, num_train_steps=num_train_steps, num_warmup_steps=num_warmup_steps
)
model.compile(
    optimizer=optimizer,
    loss=SparseCategoricalCrossentropy(from_logits=True),
    metrics=["accuracy"]
)

history = model.fit(
    tf_train_dataset,
    validation_data=tf_eval_dataset,
    epochs=num_epochs,
    callbacks=[push_to_hub_callback] # Use the HF callback
)
print("\nTraining finished using PushToHubCallback.")
successful_callback = "PushToHubCallback"
checkpoint_filepath_used = hf_callback_checkpoint_dir # Path where the best model is saved (directory)
# Out:
# Attempting fallback training using PushToHubCallback...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# /content/wav2vec2_librisevoc_checkpoints/best_model_hf_callback is already a clone of https://huggingface.co/ronanhansel/deepfake-audio-detector. Make sure you pull the latest changes with `repo.git_pull()`.
# WARNING:huggingface_hub.repository:/content/wav2vec2_librisevoc_checkpoints/best_model_hf_callback is already a clone of https://huggingface.co/ronanhansel/deepfake-audio-detector. Make sure you pull the latest changes with `repo.git_pull()`.
# PushToHubCallback configured to save best model locally in: wav2vec2_librisevoc_checkpoints/best_model_hf_callback
# Epoch 1/3
# 154/154 [==============================] - 277s 1s/step - loss: 0.0487 - accuracy: 0.9837 - val_loss: 0.1471 - val_accuracy: 0.9613
# Epoch 2/3
# 154/154 [==============================] - 341s 2s/step - loss: 0.0380 - accuracy: 0.9898 - val_loss: 0.0253 - val_accuracy: 0.9884
# Epoch 3/3
# 154/154 [==============================] - 324s 2s/step - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.0328 - val_accuracy: 0.9884
#
# Training finished using PushToHubCallback.

# %%
print("\n--- Evaluating Model ---")
# Load and evaluate the best model saved by the successful callback
best_model = None

print(f"\nAttempting to load and evaluate BEST model from checkpoint ({successful_callback}): {checkpoint_filepath_used}...")


print(f"(Loading from directory: {checkpoint_filepath_used})")
# HF callback saves in TF SavedModel format within the output_dir
best_model = TFAutoModelForAudioClassification.from_pretrained(checkpoint_filepath_used)
# Re-compile the loaded model as optimizer state might not be saved/loaded correctly this way
# Use a simple optimizer just for evaluation compilation
best_model.compile(loss=SparseCategoricalCrossentropy(from_logits=True), metrics=["accuracy"])

if best_model:
    print(f"Successfully loaded best model.")
    best_loss, best_accuracy = best_model.evaluate(tf_test_dataset)
    print(f"--- Best Model Test Loss: {best_loss:.4f}")
    print(f"--- Best Model Test Accuracy: {best_accuracy:.4f}")
else:
      print("Failed to load best model for evaluation.")
# Out:
# --- Evaluating Model ---
#
# Evaluating final model state...
# 33/33 [==============================] - 17s 500ms/step - loss: 0.0511 - accuracy: 0.9867
# /usr/local/lib/python3.11/dist-packages/transformers/configuration_utils.py:311: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
#
# TFWav2Vec2ForSequenceClassification has backpropagation operations that are NOT supported on CPU. If you wish to train/fine-tune this model, you need a GPU or a TPU
# Final Model Test Loss: 0.0511
# Final Model Test Accuracy: 0.9867
#
# Attempting to load and evaluate BEST model from checkpoint (PushToHubCallback): wav2vec2_librisevoc_checkpoints/best_model_hf_callback...
# (Loading from directory: wav2vec2_librisevoc_checkpoints/best_model_hf_callback)
# All model checkpoint layers were used when initializing TFWav2Vec2ForSequenceClassification.
#
# All the layers of TFWav2Vec2ForSequenceClassification were initialized from the model checkpoint at wav2vec2_librisevoc_checkpoints/best_model_hf_callback.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFWav2Vec2ForSequenceClassification for predictions without further training.
# Successfully loaded best model.
# 33/33 [==============================] - 26s 477ms/step - loss: 0.0511 - accuracy: 0.9867
# --- Best Model Test Loss: 0.0511
# --- Best Model Test Accuracy: 0.9867

# %%
from huggingface_hub import HfApi
api = HfApi()

api.upload_large_folder(
    repo_id=hub_model_id,
    repo_type="model",
    folder_path=push_to_hub_callback.output_dir,
)
# Out:
# Recovering from metadata files:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------- 2025-05-06 02:40:31 (0:00:00) ----------
# Files:   hashed 0/5 (0.0/378.6M) | pre-uploaded: 0/0 (0.0/378.6M) (+5 unsure) | committed: 0/5 (0.0/378.6M) | ignored: 0
# Workers: hashing: 2 | get upload mode: 0 | pre-uploading: 0 | committing: 0 | waiting: 0
# ---------------------------------------------------
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.

# %% [markdown]
# # Inferencing

# %%
import librosa
import numpy as np
import tensorflow as tf # Import TensorFlow

# Make sure id2label is defined from your training setup
# Example: id2label = {0: 'diffwave', 1: 'gt', ...}

def classify_audio(model, file_path, feature_extractor, id2label):
    """Classifies an audio file using the provided TF Wav2Vec2 model."""
    target_sr = 16000
    max_duration_s = 4.0
    max_length = int(target_sr * max_duration_s)

    try:
        # 1. Load and Resample Audio
        audio, sr = librosa.load(file_path, sr=target_sr) # Ensure loading at target SR

        # 2. Extract Features
        inputs = feature_extractor(
            audio,
            sampling_rate=feature_extractor.sampling_rate,
            max_length=max_length,
            truncation=True,
            padding='max_length',
            return_attention_mask=True,
            return_tensors="np" # Get numpy arrays first
        )

        # 3. Prepare Tensors for TF Model
        # Ensure input_values is 1D before adding batch dim, then convert to TF Tensor
        input_values_np = inputs["input_values"].squeeze() # Remove any extra dims if present
        if input_values_np.ndim == 0: # Handle potential scalar case if audio is empty/too short after processing
             input_values_np = np.zeros(max_length) # Pad if necessary
        elif input_values_np.ndim > 1:
             print(f"Warning: input_values had unexpected ndim {input_values_np.ndim}, squeezing.")
             input_values_np = np.squeeze(input_values_np)


        input_values = tf.constant(np.expand_dims(input_values_np, axis=0), dtype=tf.float32)

        # Ensure attention_mask is 1D before adding batch dim, then convert to TF Tensor
        attention_mask_np = inputs["attention_mask"].squeeze()
        if attention_mask_np.ndim == 0:
             attention_mask_np = np.ones(max_length) # Pad if necessary
        elif attention_mask_np.ndim > 1:
             print(f"Warning: attention_mask had unexpected ndim {attention_mask_np.ndim}, squeezing.")
             attention_mask_np = np.squeeze(attention_mask_np)

        attention_mask = tf.constant(np.expand_dims(attention_mask_np, axis=0), dtype=tf.int32) # TF expects int32/64

        # --- Debugging: Check Shape ---
        print(f"Shape passed to model - input_values: {input_values.shape}, attention_mask: {attention_mask.shape}")
        # Expected shape: (1, 64000) for both

        # 4. Model Inference
        # Pass tensors to the model
        logits = model(input_values, attention_mask=attention_mask).logits

        # 5. Get Prediction
        predicted_class_id = int(tf.argmax(logits, axis=-1)[0].numpy())
        predicted_label = id2label.get(predicted_class_id, "Unknown") # Use .get for safety

        return predicted_label

    except Exception as e:
        print(f"Error classifying {file_path}: {e}")
        # You might want to print the full traceback for more detailed debugging
        import traceback
        traceback.print_exc()
        return None


test_dir = "./test/"
if not os.path.exists(test_dir):
    os.makedirs(test_dir)
    print(f"Created test directory: {test_dir}")
    # You might need to copy some test files into it here if it was empty
    # Example: !cp /path/to/your/test_audio.wav ./test/

print(f"\nClassifying files in {test_dir}...")
files_processed = 0
for filename in os.listdir(test_dir):
    if filename.lower().endswith(".wav"):
        file_path = os.path.join(test_dir, filename)
        print(f"\nProcessing: {filename}")
        predicted_label = classify_audio(best_model, file_path, feature_extractor, id2label)
        if predicted_label:
            print(f"File: {filename}, Predicted Class: {predicted_label}")
            files_processed += 1
        else:
            print(f"Failed to classify {filename}.")

if files_processed == 0:
    print(f"\nWarning: No .wav files were found or processed in {test_dir}.")
# Out:
# Classifying files in ./test/...
#
# Processing: wavenet.wav
# Shape passed to model - input_values: (1, 64000), attention_mask: (1, 64000)
# File: wavenet.wav, Predicted Class: wavenet
#
# Processing: diffwave.wav
# Shape passed to model - input_values: (1, 64000), attention_mask: (1, 64000)
# File: diffwave.wav, Predicted Class: diffwave
#
# Processing: melgan.wav
# Shape passed to model - input_values: (1, 64000), attention_mask: (1, 64000)
# File: melgan.wav, Predicted Class: melgan
#
# Processing: parallel_wave_gan.wav
# Shape passed to model - input_values: (1, 64000), attention_mask: (1, 64000)
# File: parallel_wave_gan.wav, Predicted Class: parallel_wave_gan
#
# Processing: wavegrad.wav
# Shape passed to model - input_values: (1, 64000), attention_mask: (1, 64000)
# File: wavegrad.wav, Predicted Class: wavegrad
#
# Processing: gt.wav
# Shape passed to model - input_values: (1, 64000), attention_mask: (1, 64000)
# File: gt.wav, Predicted Class: gt
#
# Processing: wavernn.wav
# Shape passed to model - input_values: (1, 64000), attention_mask: (1, 64000)
# File: wavernn.wav, Predicted Class: wavenet

# %%
# !cp wavegrad.wav test/wavegrad.wav
